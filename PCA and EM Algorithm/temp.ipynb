# %%
import numpy as np
import matplotlib.pyplot as plt

data_file = "3D_data_points.txt"
D = np.loadtxt(data_file, delimiter=',')

# %%
import pandas as pd
def plot_data(data, title, save_path=None):
    if isinstance(data, pd.DataFrame):
        data = data.to_numpy()
    plt.scatter(data[:, 0], data[:, 1])
    plt.title(title)
    plt.xlabel('Principal Axis 1')
    plt.ylabel('Principal Axis 2')
    if save_path:
        plt.savefig(save_path)
    else:
        plt.show()

# %%
import pandas as pd
#convert data to pandas dataframe
df = pd.DataFrame(data=D, columns=['x','y','z'])

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

#perform pca using svd
U, S, V = np.linalg.svd(df, full_matrices=False)
transformed_df = np.dot(df, V.T)


#plot the data
plot_data(transformed_df, 'Transformed Data', 'transformed_data.png')
